# %%
#!/usr/bin/env -S python3 -u 
"""
usage:precisiontest.ipynb

options:

description:
    This notebook contains code to test the precision libraries in python and determine the impact on our research. 

"""
__author__      = 'Eduardo Marsola do Nascimento'
__copyright__   = 'Copyright 2026-04-12'
__credits__     = ''
__license__     = 'MIT'
__version__     = '1.00'
__maintainer__  = ''
__email__       = ''
__status__      = 'Production'
__printdebug__  = False


"""
to prepare the environment
1. create a virtual environment: 
    python -m venv ./venv
2. upgrade pip: 
    python -m pip install --upgrade pip
3. install libraries:
## installing NumPy and MatPlotLib
    pip install numpy
    pip install matplotlib
## installing PyCryptodome
    pip install pycryptodome
## installing Qiskit
    pip install qiskit
    pip install qiskit-aer
    pip install qiskit-ibm-runtime
    pip install pylatexenc

## installing mpmath
    pip install mpmath
"""

# !pip install numpy
# !pip install matplotlib
# !pip install pycryptodome
# !pip install qiskit
# !pip install qiskit-aer
# !pip install qiskit-ibm-runtime
# !pip install pylatexenc
# !pip install mpmath
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: numpy in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.3.4)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: numpy>=1.23 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.3.4)
# Requirement already satisfied: packaging>=20.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pycryptodome in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (3.23.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.3.1)
# Requirement already satisfied: rustworkx>=0.15.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit) (0.17.1)
# Requirement already satisfied: numpy<3,>=1.21 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit) (2.3.4)
# Requirement already satisfied: scipy>=1.5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit) (1.17.1)
# Requirement already satisfied: dill>=0.3 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit) (5.7.0)
# Requirement already satisfied: typing-extensions in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit) (4.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit-aer in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.17.2)
# Requirement already satisfied: qiskit>=1.1.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-aer) (2.3.1)
# Requirement already satisfied: numpy>=1.16.3 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-aer) (2.3.4)
# Requirement already satisfied: scipy>=1.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-aer) (1.17.1)
# Requirement already satisfied: psutil>=5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-aer) (7.1.3)
# Requirement already satisfied: python-dateutil>=2.8.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-aer) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.8.0->qiskit-aer) (1.17.0)
# Requirement already satisfied: rustworkx>=0.15.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.17.1)
# Requirement already satisfied: dill>=0.3 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=1.1.0->qiskit-aer) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=1.1.0->qiskit-aer) (5.7.0)
# Requirement already satisfied: typing-extensions in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=1.1.0->qiskit-aer) (4.15.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: qiskit-ibm-runtime in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (0.46.1)
# Requirement already satisfied: requests>=2.32.4 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (2.33.1)
# Requirement already satisfied: requests-ntlm>=1.1.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (1.3.0)
# Requirement already satisfied: numpy>=1.26 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (2.3.4)
# Requirement already satisfied: urllib3>=2.4.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (2.6.3)
# Requirement already satisfied: python-dateutil>=2.9.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (2.9.0.post0)
# Requirement already satisfied: ibm-platform-services>=0.55.3 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (0.74.0)
# Requirement already satisfied: ibm-quantum-schemas>=0.5.20260320 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (0.5.20260320)
# Requirement already satisfied: pydantic>=2.7.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (2.12.5)
# Requirement already satisfied: qiskit>=2.2.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (2.3.1)
# Requirement already satisfied: packaging in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (25.0)
# Requirement already satisfied: pybase64>=1.4 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (1.4.3)
# Requirement already satisfied: samplomatic>=0.13.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: ibm_cloud_sdk_core<4.0.0,>=3.24.4 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (3.24.4)
# Requirement already satisfied: PyJWT<3.0.0,>=2.11.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from ibm_cloud_sdk_core<4.0.0,>=3.24.4->ibm-platform-services>=0.55.3->qiskit-ibm-runtime) (2.12.1)
# Requirement already satisfied: six>=1.5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from python-dateutil>=2.9.0->qiskit-ibm-runtime) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (3.11)
# Requirement already satisfied: certifi>=2023.5.7 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests>=2.32.4->qiskit-ibm-runtime) (2026.2.25)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pydantic>=2.7.0->qiskit-ibm-runtime) (0.4.2)
# Requirement already satisfied: rustworkx>=0.15.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (0.17.1)
# Requirement already satisfied: scipy>=1.5 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (1.17.1)
# Requirement already satisfied: dill>=0.3 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (0.4.1)
# Requirement already satisfied: stevedore>=3.0.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from qiskit>=2.2.0->qiskit-ibm-runtime) (5.7.0)
# Requirement already satisfied: cryptography>=1.3 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (46.0.6)
# Requirement already satisfied: pyspnego>=0.4.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.12.1)
# Requirement already satisfied: cffi>=2.0.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (2.0.0)
# Requirement already satisfied: pycparser in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from cffi>=2.0.0->cryptography>=1.3->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (3.0)
# Requirement already satisfied: sspilib>=0.3.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from pyspnego>=0.4.0->requests-ntlm>=1.1.0->qiskit-ibm-runtime) (0.5.0)
# Requirement already satisfied: orjson>=3.9.0 in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (from samplomatic>=0.13.0->qiskit-ibm-runtime) (3.11.8)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pylatexenc in C:\Users\eduna\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages (2.10)
# Defaulting to user installation because normal site-packages is not writeable
# Collecting mpmath
#   Downloading mpmath-1.4.1-py3-none-any.whl.metadata (9.1 kB)
# Downloading mpmath-1.4.1-py3-none-any.whl (567 kB)
#    ---------------------------------------- 0.0/567.8 kB ? eta -:--:--
#    ---------------------------------------- 567.8/567.8 kB 7.4 MB/s  0:00:00
# Installing collected packages: mpmath
# Successfully installed mpmath-1.4.1

# %%
#!/usr/bin/env -S python3 -u 
"""
usage:precisiontest.ipynb

options:

description:
    This notebook contains code to test the precision libraries in python and determine the impact on our research. 

"""

## carrega bibliotecas
import qiskit
import Crypto
import decimal

from decimal import *

from datetime import datetime
from Crypto.Util import number
from Crypto.Random import random
import matplotlib.pyplot as plt
import numpy as np
import mpmath as mp
import math

from fractions import Fraction

from qiskit import QuantumCircuit
from qiskit.quantum_info import Statevector


print(f'qiskit.__version__={qiskit.__version__}')
print(f'numpy.__version__={np.__version__}')
print(f'decimal.__version__={decimal.__version__}')
print(f'Crypto.__version__={Crypto.__version__}')
print(f'mpmath.__version__={mp.__version__}')

# 2^4097 +-= 10^1233 -- 1500 digits
getcontext().prec = 1500
mp.mp.dps = 1500
# Out:
# qiskit.__version__=2.3.1
# numpy.__version__=2.3.4
# decimal.__version__=1.70
# Crypto.__version__=3.23.0
# mpmath.__version__=1.4.1

# %%
# sin / cos / exp differencies from pi/2 to pi/2**1024

def print_results(denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x):
    print("denominator: ")
    [print(f'   2**{2**i:<5}: {denominator[i]}') for i in range(len(denominator))]
    print("x: ")
    [print(f'pi/2**{2**i:<5}: {x[i]}') for i in range(len(x))]
    print("sin(x): ")
    [print(f'sin(pi/2**{2**i:<5}):   {sin_x[i]}') for i in range(len(sin_x))]
    print("cos(x): ")
    [print(f'cos(pi/2**{2**i:<5}):   {cos_x[i]}') for i in range(len(cos_x))]
    print("exp(x): ")
    [print(f'exp(pi/2**{2**i:<5}):   {exp_x[i]}') for i in range(len(exp_x))]
    print("x - sin(x): ")
    [print(f'x-sin(pi/2**{2**i:<5}):   {_x_minus_sin_x[i]}') for i in range(len(_x_minus_sin_x))]
    print("1 - cos(x): ")
    [print(f'1-cos(pi/2**{2**i:<5}):   {_1_minus_cos_x[i]}') for i in range(len(_1_minus_cos_x))]
    print("1 - exp(x): ")
    [print(f'1-exp(pi/2**{2**i:<5}):   {_1_minus_exp_x[i]}') for i in range(len(_1_minus_exp_x))]


def get_results_Decimal(max_i=13):
     denominator = 2**(np.array([Decimal(2)**i for i in range(max_i)]))
     x = Decimal(np.pi) / denominator
     sin_x = np.array([Decimal(math.sin(float(xi))) for xi in x])
     cos_x = np.array([Decimal(math.cos(float(xi))) for xi in x])
     exp_x = np.array([Decimal(math.exp(float(xi))) for xi in x])
     _x_minus_sin_x = x - sin_x
     _1_minus_cos_x = 1 - cos_x
     _1_minus_exp_x = 1 - exp_x
     return (denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

def get_results_float64(max_i=13):
    denominator = 2**(np.array([np.float64(2)**i for i in range(max_i)]))
    x = np.float64(np.pi) / denominator
    sin_x = np.sin(x)
    cos_x = np.cos(x)
    exp_x = np.exp(x)
    _x_minus_sin_x = x - sin_x
    _1_minus_cos_x = 1 - cos_x
    _1_minus_exp_x = 1 - exp_x
    return (denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

def get_results_float128(max_i=13):
    denominator = 2**(np.array([np.float128(2)**i for i in range(max_i)]))
    x = np.float128(np.pi) / denominator
    sin_x = np.sin(x)
    cos_x = np.cos(x)
    exp_x = np.exp(x)
    _x_minus_sin_x = x - sin_x
    _1_minus_cos_x = 1 - cos_x
    _1_minus_exp_x = 1 - exp_x
    return (denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

def get_results_mp(max_i=13):
    denominator = 2**(np.array([mp.mpf(2)**i for i in range(max_i)]))
    x = mp.mp.pi / denominator
    sin_x = np.array([mp.mp.sin(float(xi)) for xi in x])
    cos_x = np.array([mp.mp.cos(float(xi)) for xi in x])
    exp_x = np.array([mp.mp.exp(float(xi)) for xi in x])
    _x_minus_sin_x = x - sin_x
    _1_minus_cos_x = 1 - cos_x
    _1_minus_exp_x = 1 - exp_x
    return (denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

def precision_test():
    print('Calculating sin, cos and exp for x = pi/2**i, i=0..12 - using float64')
    print('')
    denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x = get_results_float64()
    print_results(denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

    if hasattr(np, "float128"):
        print('')
        print('')
        print('Calculating sin, cos and exp for x = pi/2**i, i=0..12 - using float128')
        print('')
        denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x = get_results_float128()
        print_results(denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

    print('')
    print('')
    print('Calculating sin, cos and exp for x = pi/2**i, i=0..12 - using Decimal with 1500 digits of precision')
    print('')
    denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x = get_results_Decimal()
    print_results(denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

    print('')
    print('')
    print('Calculating sin, cos and exp for x = pi/2**i, i=0..12 - using mpmath with 1500 digits of precision')
    print('')
    denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x = get_results_mp()
    print_results(denominator, x, sin_x, cos_x, exp_x, _x_minus_sin_x, _1_minus_cos_x, _1_minus_exp_x)

    print('')
    print('Done.')
    
if __name__ == "__main__":
    precision_test()
# Out:
# Calculating sin, cos and exp for x = pi/2**i, i=0..12 - using float64
#
# denominator:
#    2**1    : 2.0
#    2**2    : 4.0
#    2**4    : 16.0
#    2**8    : 256.0
#    2**16   : 65536.0
#    2**32   : 4294967296.0
#    2**64   : 1.8446744073709552e+19
#    2**128  : 3.402823669209385e+38
#    2**256  : 1.157920892373162e+77
#    2**512  : 1.3407807929942597e+154
#    2**1024 : inf
#    2**2048 : inf
#    2**4096 : inf
# x:
# pi/2**1    : 1.5707963267948966
# pi/2**2    : 0.7853981633974483
# pi/2**4    : 0.19634954084936207
# pi/2**8    : 0.01227184630308513
# pi/2**16   : 4.7936899621426287e-05
# pi/2**32   : 7.314590396335798e-10
# pi/2**64   : 1.7030607900432772e-19
# pi/2**128  : 9.232311042199004e-39
# pi/2**256  : 2.7131323687847886e-77
# pi/2**512  : 2.3431068449108095e-154
# pi/2**1024 : 0.0
# pi/2**2048 : 0.0
# pi/2**4096 : 0.0
# sin(x):
# sin(pi/2**1    ):   1.0
# sin(pi/2**2    ):   0.7071067811865476
# sin(pi/2**4    ):   0.19509032201612825
# sin(pi/2**8    ):   0.012271538285719925
# sin(pi/2**16   ):   4.793689960306688e-05
# sin(pi/2**32   ):   7.314590396335798e-10
# sin(pi/2**64   ):   1.7030607900432772e-19
# sin(pi/2**128  ):   9.232311042199004e-39
# sin(pi/2**256  ):   2.7131323687847886e-77
# sin(pi/2**512  ):   2.3431068449108095e-154
# sin(pi/2**1024 ):   0.0
# sin(pi/2**2048 ):   0.0
# sin(pi/2**4096 ):   0.0
# cos(x):
# cos(pi/2**1    ):   6.123233995736766e-17
# cos(pi/2**2    ):   0.7071067811865476
# cos(pi/2**4    ):   0.9807852804032304
# cos(pi/2**8    ):   0.9999247018391445
# cos(pi/2**16   ):   0.9999999988510269
# cos(pi/2**32   ):   1.0
# cos(pi/2**64   ):   1.0
# cos(pi/2**128  ):   1.0
# cos(pi/2**256  ):   1.0
# cos(pi/2**512  ):   1.0
# cos(pi/2**1024 ):   1.0
# cos(pi/2**2048 ):   1.0
# cos(pi/2**4096 ):   1.0
# exp(x):
# exp(pi/2**1    ):   4.810477380965351
# exp(pi/2**2    ):   2.1932800507380152
# exp(pi/2**4    ):   1.2169522055076403
# exp(pi/2**8    ):   1.0123474543759297
# exp(pi/2**16   ):   1.000047938048613
# exp(pi/2**32   ):   1.0000000007314591
# exp(pi/2**64   ):   1.0
# exp(pi/2**128  ):   1.0
# exp(pi/2**256  ):   1.0
# exp(pi/2**512  ):   1.0
# exp(pi/2**1024 ):   1.0
# exp(pi/2**2048 ):   1.0
# exp(pi/2**4096 ):   1.0
# x - sin(x):
# x-sin(pi/2**1    ):   0.5707963267948966
# x-sin(pi/2**2    ):   0.0782913822109007
# x-sin(pi/2**4    ):   0.0012592188332338217
# x-sin(pi/2**8    ):   3.0801736520397194e-07
# x-sin(pi/2**16   ):   1.835940525041907e-14
# x-sin(pi/2**32   ):   0.0
# x-sin(pi/2**64   ):   0.0
# x-sin(pi/2**128  ):   0.0
# x-sin(pi/2**256  ):   0.0
# x-sin(pi/2**512  ):   0.0
# x-sin(pi/2**1024 ):   0.0
# x-sin(pi/2**2048 ):   0.0
# x-sin(pi/2**4096 ):   0.0
# 1 - cos(x):
# 1-cos(pi/2**1    ):   0.9999999999999999
# 1-cos(pi/2**2    ):   0.2928932188134524
# 1-cos(pi/2**4    ):   0.01921471959676957
# 1-cos(pi/2**8    ):   7.529816085549701e-05
# 1-cos(pi/2**16   ):   1.1489731388536484e-09
# 1-cos(pi/2**32   ):   0.0
# 1-cos(pi/2**64   ):   0.0
# 1-cos(pi/2**128  ):   0.0
# 1-cos(pi/2**256  ):   0.0
# 1-cos(pi/2**512  ):   0.0
# 1-cos(pi/2**1024 ):   0.0
# 1-cos(pi/2**2048 ):   0.0
# 1-cos(pi/2**4096 ):   0.0
# 1 - exp(x):
# 1-exp(pi/2**1    ):   -3.8104773809653514
# 1-exp(pi/2**2    ):   -1.1932800507380152
# 1-exp(pi/2**4    ):   -0.21695220550764027
# 1-exp(pi/2**8    ):   -0.012347454375929656
# 1-exp(pi/2**16   ):   -4.793804861291662e-05
# 1-exp(pi/2**32   ):   -7.314591154994332e-10
# 1-exp(pi/2**64   ):   0.0
# 1-exp(pi/2**128  ):   0.0
# 1-exp(pi/2**256  ):   0.0
# 1-exp(pi/2**512  ):   0.0
# 1-exp(pi/2**1024 ):   0.0
# 1-exp(pi/2**2048 ):   0.0
# 1-exp(pi/2**4096 ):   0.0
#
#
# Calculating sin, cos and exp for x = pi/2**i, i=0..12 -
# exp(pi/2**2    ):   2.19328005073801524105192584102042019367218017578125
# exp(pi/2**4    ):   1.2169522055076402722306738724000751972198486328125
# exp(pi/2**8    ):   1.0123474543759296562228655602666549384593963623046875
# exp(pi/2**16   ):   1.000047938048612916617230439442209899425506591796875
# exp(pi/2**32   ):   1.0000000007314591154994332100613974034786224365234375
# exp(pi/2**64   ):   1
# exp(pi/2**128  ):   1
# exp(pi/2**256  ):   1
# exp(pi/2**512  ):   1
# exp(pi/2**1024 ):   1
# exp(pi/2**2048 ):   1
# exp(pi/2**4096 ):   1
# x - sin(x):
# x-sin(pi/2**1    ):   0.5707963267948965579989817342720925807952880859375
# x-sin(pi/2**2    ):   0.07829138221090070626217993776663206517696380615234375
# x-sin(pi/2**4    ):   0.001259218833233821666084395474172197282314300537109375
# x-sin(pi/2**8    ):   3.08017365203971937859250829205848276615142822265625E-7
# x-sin(pi/2**16   ):   1.8359405250419069677292327469331212341785430908203125E-14
# x-sin(pi/2**32   ):   0E-80
# x-sin(pi/2**64   ):   0E-112
# x-sin(pi/2**128  ):   0E-176
# x-sin(pi/2**256  ):   0E-304
# x-sin(pi/2**512  ):   0E-560
# x-sin(pi/2**1024 ):   0E-1072
# x-sin(pi/2**2048 ):   9....-617
# x-sin(pi/2**4096 ):   3....-1233
# 1 - cos(x):
# 1-cos(pi/2**1    ):   0.9999999999999999387676600426323396413117985270801697687153937661209968101871936596580781042575836181640625
# 1-cos(pi/2**2    ):   0.29289321881345242726268907063058577477931976318359375
# 1-cos(pi/2**4    ):   0.0192147195967695694207577616907656192779541015625
# 1-cos(pi/2**8    ):   0.00007529816085549700943602147162891924381256103515625
# 1-cos(pi/2**16   ):   1.1489731388536483791540376842021942138671875E-9
# 1-cos(pi/2**32   ):   0
# 1-cos(pi/2**64   ):   0
# 1-cos(pi/2**128  ):   0
# 1-cos(pi/2**256  ):   0
# 1-cos(pi/2**512  ):   0
# 1-cos(pi/2**1024 ):   0
# 1-cos(pi/2**2048 ):   0
# 1-cos(pi/2**4096 ):   0
# 1 - exp(x):
# 1-exp(pi/2**1    ):   -3.81047738096535137941600623889826238155364990234375
# 1-exp(pi/2**2    ):   -1.19328005073801524105192584102042019367218017578125
# 1-exp(pi/2**4    ):   -0.2169522055076402722306738724000751972198486328125
# 1-exp(pi/2**8    ):   -0.0123474543759296562228655602666549384593963623046875
# 1-exp(pi/2**16   ):   -0.000047938048612916617230439442209899425506591796875
# 1-exp(pi/2**32   ):   -7.314591154994332100613974034786224365234375E-10
# 1-exp(pi/2**64   ):   0
# 1-exp(pi/2**128  ):   0
# 1-exp(pi/2**256  ):   0
# 1-exp(pi/2**512  ):   0
# 1-exp(pi/2**1024 ):   0
# 1-exp(pi/2**2048 ):   0
# 1-exp(pi/2**4096 ):   0
#
#
# Calculating sin, cos and exp for x = pi/2**i, i=0..12 - using mpmath with 1500 digits of precision
#
# denominator:
#    2**1    : 2.0
#    2**2    : 4.0
#    2**4    : 16.0
#    2**8    : 256.0
#    2**16   : 65536.0
